# %%
# Install packages
# !pip install smartapi-python
# !pip install logzero
# !pip install pyotp
# !pip install websocket-client
# !pip install ijson
# Out:
# Collecting smartapi-python
#   Downloading smartapi_python-1.5.4-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.11/dist-packages (from smartapi-python) (2.32.3)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from smartapi-python) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.11/dist-packages (from smartapi-python) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.18.4->smartapi-python) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.18.4->smartapi-python) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.18.4->smartapi-python) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.18.4->smartapi-python) (2024.12.14)
# Downloading smartapi_python-1.5.4-py3-none-any.whl (28 kB)
# Installing collected packages: smartapi-python
# Successfully installed smartapi-python-1.5.4
# Collecting logzero
#   Downloading logzero-1.7.0-py2.py3-none-any.whl.metadata (11 kB)
# Downloading logzero-1.7.0-py2.py3-none-any.whl (16 kB)
# Installing collected packages: logzero
# Successfully installed logzero-1.7.0
# Collecting pyotp
#   Downloading pyotp-2.9.0-py3-none-any.whl.metadata (9.8 kB)
# Downloading pyotp-2.9.0-py3-none-any.whl (13 kB)
# Installing collected packages: pyotp
# Successfully installed pyotp-2.9.0
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.11/dist-packages (1.8.0)
# Collecting ijson
#   Downloading ijson-3.3.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (21 kB)
# Downloading ijson-3.3.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (119 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.2/119.2 kB 6.1 MB/s eta 0:00:00
# Installing collected packages: ijson
# Successfully installed ijson-3.3.0

# %%
# Set time zone to IST
# !rm /etc/localtime
# !ln -s /usr/share/zoneinfo/Asia/Kolkata /etc/localtime
# !date
# Out:
# Mon Jan 27 08:30:59 AM IST 2025

# %%
# package import statement
from SmartApi import SmartConnect #or from SmartApi.smartConnect import SmartConnect
import pyotp
from logzero import logger
from datetime import time, timedelta, datetime
import ijson
import json
import time
import requests

api_key = 'key'
username = 'user'
pwd = 'pin'
smartApi = SmartConnect(api_key)
try:
    token = "token"
    totp = pyotp.TOTP(token).now()
except Exception as e:
    logger.error("Invalid Token: The provided token is not valid.")
    raise e

correlation_id = "abcde"
data = smartApi.generateSession(username, pwd, totp)


if data['status'] == False:
    logger.error(data)

else:
    # login api call
    # logger.info(f"You Credentials: {data}")
    authToken = data['data']['jwtToken']
    refreshToken = data['data']['refreshToken']
    # fetch the feedtoken
    feedToken = smartApi.getfeedToken()
    # fetch User Profile
    res = smartApi.getProfile(refreshToken)
    smartApi.generateToken(refreshToken)
    res=res['data']['exchanges']


    def fetch_price(exchange, symbol, token):
        data = smartApi.ltpData(exchange, symbol, token)
        return data['data']['ltp']


    def find_nearest_expiry(url, strike_price):
        # Fetch the JSON data
        response = requests.get(url)
        data = json.loads(response.text)

        # Normalize the strike price
        normalized_strike = str(int(float(strike_price) * 100))

        # Separate lists for CE and PE options
        ce_options = []
        pe_options = []
        latest_ce = None
        latest_pe = None

        for entry in data:
            # Normalize the strike price from JSON
            json_strike = str(int(float(entry['strike'])))

            if (json_strike == normalized_strike and
                entry['exch_seg'] == "NFO" and
                entry['name'] == "NIFTY"):

                expiry_date = datetime.strptime(entry['expiry'], "%d%b%Y").date()

                if entry['symbol'][-2:] == "CE":
                    if latest_ce is None or expiry_date < datetime.strptime(latest_ce['expiry'], "%d%b%Y").date():
                        latest_ce = entry
                elif entry['symbol'][-2:] == "PE":
                    if latest_pe is None or expiry_date < datetime.strptime(latest_pe['expiry'], "%d%b%Y").date():
                        latest_pe = entry

        print(f"Latest CE: {latest_ce}")
        print(f"Latest PE: {latest_pe}")

        return {
            'CE': latest_ce,
            'PE': latest_pe
        }




    # Fetch Nifty price
    nifty_future = fetch_price("NFO", "NIFTY30JAN25FUT", "35006")
    print(f"Nifty future price: {nifty_future}")

    strike_price = round(nifty_future / 50) * 50
    print(f"Strike price: {strike_price}")

    json_url = "https://margincalculator.angelbroking.com/OpenAPI_File/files/OpenAPIScripMaster.json"

    # Find nearest CE and PE
    options = find_nearest_expiry(json_url, strike_price)

    price_cmp = fetch_price("NFO", options['CE']['symbol'], options['CE']['token'])
    price_pmp = fetch_price("NFO", options['PE']['symbol'], options['PE']['token'])

    print(f"CE price: {price_cmp}")
    print(f"PE price: {price_pmp}")

    sell_cmp_params = {
        'variety': 'NORMAL',
        'tradingsymbol': options['CE']['symbol'],
        'symboltoken': options['CE']['token'],
        'transactiontype': 'SELL',
        'exchange': 'NFO',
        'ordertype': 'LIMIT',
        'producttype': 'INTRADAY',
        'duration': 'DAY',
        'price': int(price_cmp*.975),
        'quantity': 25
    }

    try:
        sell_order_id_c = smartApi.placeOrder(sell_cmp_params)
        print(f"Sell Call order placed successfully, Order ID: {sell_order_id_c}")
    except Exception as e:
        print(f"An error occurred placing sell order: {e}")

    sell_pmp_params = {
        'variety': 'NORMAL',
        'tradingsymbol': options['PE']['symbol'],
        'symboltoken': options['PE']['token'],
        'transactiontype': 'SELL',
        'exchange': 'NFO',
        'ordertype': 'LIMIT',
        'producttype': 'INTRADAY',
        'duration': 'DAY',
        'price': int(price_pmp*.975),
        'quantity': 25
    }

    try:
        sell_order_id_p = smartApi.placeOrder(sell_pmp_params)
        print(f"Sell Put order placed successfully, Order ID: {sell_order_id_p}")
    except Exception as e:
        print(f"An error occurred placing sell order: {e}")

    # Wait a bit to ensure the sell order is placed before placing the stop loss
    time.sleep(5)

    OrderBook = smartApi.orderBook()['data']
    for i in OrderBook:
        if i['orderid'] == sell_order_id_c:
            price_sold_c = i['averageprice']
        if i['orderid'] == sell_order_id_p:
            price_sold_p = i['averageprice']


    stop_loss_c = price_sold_c * 1.30
    stop_loss_p = price_sold_p * 1.30

    stop_loss_cmp_params = {
        'variety': 'STOPLOSS',
        'tradingsymbol': options['CE']['symbol'],
        'symboltoken': options['CE']['token'],
        'transactiontype': 'BUY',
        'exchange': 'NFO',
        'ordertype': 'STOPLOSS_LIMIT',
        'producttype': 'INTRADAY',
        'duration': 'DAY',
        'quantity': 25,
        'triggerprice' : int(stop_loss_c),
        'price' : int(stop_loss_c*1.05)
    }

    try:
        stop_loss_order_id = smartApi.placeOrder(stop_loss_cmp_params)
        print(f"Stop Loss order CE placed successfully, Order ID: {stop_loss_order_id}")
    except Exception as e:
        print(f"An error occurred placing stop loss order: {e}")


    # Assuming the sell order was placed at 'sell_price'

    stop_loss_pmp_params = {
        'variety': 'STOPLOSS',
        'tradingsymbol': options['PE']['symbol'],
        'symboltoken': options['PE']['token'],
        'transactiontype': 'BUY',
        'exchange': 'NFO',
        'ordertype': 'STOPLOSS_LIMIT',
        'producttype': 'INTRADAY',
        'duration': 'DAY',
        'quantity': 25,
        'triggerprice' : int(stop_loss_p),
        'price' : int(stop_loss_p*1.05)
    }

    try:
        stop_loss_order_id = smartApi.placeOrder(stop_loss_pmp_params)
        print(f"Stop Loss order PE placed successfully, Order ID: {stop_loss_order_id}")
    except Exception as e:
        print(f"An error occurred placing stop loss order: {e}")
# Out:
# [I 250127 10:27:57 smartConnect:124] in pool
# Nifty future price: 22869.55
# Strike price: 22850
# Latest CE: {'token': '43261', 'symbol': 'NIFTY30JAN2522850CE', 'name': 'NIFTY', 'expiry': '30JAN2025', 'strike': '2285000.000000', 'lotsize': '25', 'instrumenttype': 'OPTIDX', 'exch_seg': 'NFO', 'tick_size': '5.000000'}
# Latest PE: {'token': '43262', 'symbol': 'NIFTY30JAN2522850PE', 'name': 'NIFTY', 'expiry': '30JAN2025', 'strike': '2285000.000000', 'lotsize': '25', 'instrumenttype': 'OPTIDX', 'exch_seg': 'NFO', 'tick_size': '5.000000'}
# CE price: 188.45
# PE price: 167.35
# Sell Call order placed successfully, Order ID: 250127000322842
# Sell Put order placed successfully, Order ID: 250127000322889
# Stop Loss order CE placed successfully, Order ID: 250127000323283
# Stop Loss order PE placed successfully, Order ID: 250127000323307

# %%
modify_params = {
    'orderid' : "250127000323307",
    'variety': 'ROBO',
    'tradingsymbol': options['PE']['symbol'],
    'symboltoken': options['PE']['token'],
    'transactiontype': 'BUY',
    'exchange': 'NFO',
    'ordertype': 'STOPLOSS_LIMIT',
    'producttype': 'INTRADAY',
    'duration': 'DAY',
    'trailingStopLoss':0.50,
    'quantity': 25,
    'triggerprice' : int(stop_loss_p),
    'price' : int(stop_loss_p*1.05)
}

smartApi.modifyOrder(modify_params)
# Out:
# {'status': True,
#  'message': 'SUCCESS',
#  'errorcode': '',
#  'data': {'orderid': '250127000323307',
#   'uniqueorderid': '8712ef93-e76e-466f-8691-6021a45d679f'}}

# %%
def get_order_info(orderid):
    OrderBook = smartApi.orderBook()['data']
    for i in OrderBook:
        if i['orderid'] == orderid:
            return i


def trailing_stoploss(orderid_sl, trailing_stoploss, orderid): # trailing_stoploss =

    order_info_sl = get_order_info(orderid_sl)
    order_info = get_order_info(orderid)
    print(order_info_sl)

    new_stoploss = None

    symbol = order_info_sl['tradingsymbol']
    exchange = order_info_sl['exchange']
    token = order_info_sl['symboltoken']
    prev_price = order_info['averageprice']
    order_type = order_info_sl['transactiontype']
    prev_stoploss = order_info_sl['triggerprice']



    while True:

        curr_price = fetch_price(exchange, symbol, token)

        if order_type == 'BUY': # stoploss order for a serpe
            print("Current Price - ", curr_price)
            print("Prev Price - ", prev_price)
            if curr_price < prev_price:

                new_stoploss = int(prev_stoploss - (prev_price - curr_price) * trailing_stoploss)
                print("diff - ", (prev_price - curr_price))
                print("New Stoploss - ", new_stoploss)
        else:
            if curr_price > prev_price:

                new_stoploss = int(prev_stoploss + (curr_price - prev_price) * trailing_stoploss)

        if new_stoploss:
            new_params = order_info_sl
            new_params['triggerprice'] = new_stoploss
            new_params['price'] = int(new_stoploss * 1.05)
            prev_price = curr_price
            prev_stoploss = new_stoploss
            print(new_stoploss)
            smartApi.modifyOrder(new_params)

        time.sleep(15)

trailing_stoploss("250127000323307", 0.50, "250127000322889")
# Out:
# {'variety': 'STOPLOSS', 'ordertype': 'STOPLOSS_LIMIT', 'producttype': 'INTRADAY', 'duration': 'DAY', 'price': 228.0, 'triggerprice': 217.0, 'quantity': '25', 'disclosedquantity': '0', 'squareoff': 0.0, 'stoploss': 0.0, 'trailingstoploss': 0.0, 'tradingsymbol': 'NIFTY30JAN2522850PE', 'transactiontype': 'BUY', 'exchange': 'NFO', 'symboltoken': '43262', 'ordertag': '', 'instrumenttype': 'OPTIDX', 'strikeprice': 22850.0, 'optiontype': 'PE', 'expirydate': '30JAN2025', 'lotsize': '25', 'cancelsize': '0', 'averageprice': 0.0, 'filledshares': '0', 'unfilledshares': '25', 'orderid': '250127000323307', 'text': '', 'status': 'trigger pending', 'orderstatus': 'trigger pending', 'updatetime': '27-Jan-2025 13:59:33', 'exchtime': '27-Jan-2025 13:59:33', 'exchorderupdatetime': '27-Jan-2025 13:59:33', 'fillid': '', 'filltime': '', 'parentorderid': '', 'uniqueorderid': '8712ef93-e76e-466f-8691-6021a45d679f', 'exchangeorderid': '1100000052102891'}
# Current Price -  148.2
# Prev Price -  167.2
# diff -  19.0
# New Stoploss -  207
# 207
# Current Price -  149.75
# Prev Price -  148.2
# 207
# Current Price -  150.8
# Prev Price -  149.75
# 207
# Current Price -  151.0
# Prev Price -  150.8
# 207
# Current Price -  153.85
# Prev Price -  151.0
# 207
# Current Price -  155.6
# Prev Price -  153.85
# 207
# Current Price -  154.0
# Prev Price -  155.6
# diff -  1.5999999999999943
# New Stoploss -  206
# 206
# Current Price -  153.45
# Prev Price -  154.0
# diff -  0.5500000000000114
# New Stoploss -  205
# 205
# Current Price -  148.9
# Prev Price -  153.45
# diff -  4.549999999999983
# New Stoploss -  202
# 202
# Current Price -  152.1
# Prev Price -  148.9
# 202
# Current Price -  153.85
# Prev Price -  152.1
# 202
# Current Price -  154.25
# Prev Price -  153.85
# 202
# Current Price -  153.1
# Prev Price -  154.25
# diff -  1.1500000000000057
# New Stoploss -  201
# 201
# Current Price -  151.55
# Prev Price -  153.1
# diff -  1.549999999999983
# New Stoploss -  200
# 200
# Current Price -  152.15
# Prev Price -  151.55
# 200
# Current Price -  154.5
# Prev Price -  152.15
# 200
# Current Price -  155.95
# Prev Price -  154.5
# 200
# Current Price -  157.7
# Prev Price -  155.95
# 200
# Current Price -  159.0
# Prev Price -  157.7
# 200
# Current Price -  158.15
# Prev Price -  159.0
# diff -  0.8499999999999943
# New Stoploss -  199
# 199
# Current Price -  159.55
# Prev Price -  158.15
# 199
# Current Price -  158.5
# Prev Price -  159.55
# diff -  1.0500000000000114
# New Stoploss -  198
# 198
# Current Price -  158.0
# Prev Price -  158.5
# diff -  0.5
# New Stoploss -  197
# 197
# Current Price -  157.45
# Prev Price -  158.0
# diff -  0.5500000000000114
# New Stoploss -  196
# 196
# Current Price -  159.0
# Prev Price -  157.45
# 196
# Current Price -  157.9
# Prev Price -  159.0
# diff -  1.0999999999999943
# New Stoploss -  195
# 195
# Current Price -  156.8
# Prev Price -  157.9
# diff -  1.0999999999999943
# New Stoploss -  194
# 194
# Current Price -  154.9
# Prev Price -  156.8
# diff -  1.9000000000000057
# New Stoploss -  193
# 193
# Current Price -  152.7
# Prev Price -  154.9
# diff -  2.200000000000017
# New Stoploss -  191
# 191
# Current Price -  157.65
# Prev Price -  152.7
# 191
# Current Price -  158.65
# Prev Price -  157.65
# 191
# Current Price -  158.4
# Prev Price -  158.65
# diff -  0.25
# New Stoploss -  190
# 190
# Current Price -  161.45
# Prev Price -  158.4
# 190
# Current Price -  160.75
# Prev Price -  161.45
# diff -  0.6999999999999886
# New Stoploss -  189
# 189
# Current Price -  164.05
# Prev Price -  160.75
# 189
# Current Price -  164.95
# Prev Price -  164.05
# 189
# Current Price -  168.6
# Prev Price -  164.95
# 189
# Current Price -  166.4
# Prev Price -  168.6
# diff -  2.1999999999999886
# New Stoploss -  187
# 187
# Current Price -  163.75
# Prev Price -  166.4
# diff -  2.6500000000000057
# New Stoploss -  185
# 185
# Current Price -  163.7
# Prev Price -  163.75
# diff -  0.05000000000001137
# New Stoploss -  184
# 184
# Current Price -  169.7
# Prev Price -  163.7
# 184
# Current Price -  169.8
# Prev Price -  169.7
# 184
# Current Price -  170.0
# Prev Price -  169.8
# 184
# Current Price -  169.9
# Prev Price -  170.0
# diff -  0.09999999999999432
# New Stoploss -  183
# 183
# Current Price -  171.15
# Prev Price -  169.9
# 183
# Current Price -  170.7
# Prev Price -  171.15
# diff -  0.45000000000001705
# New Stoploss -  182
# 182
# Current Price -  170.5
# Prev Price -  170.7
# diff -  0.19999999999998863
# New Stoploss -  181
# 181
# Current Price -  169.15
# Prev Price -  170.5
# diff -  1.3499999999999943
# New Stoploss -  180
# 180
# Current Price -  168.35
# Prev Price -  169.15
# diff -  0.8000000000000114
# New Stoploss -  179
# 179
# Current Price -  168.05
# Prev Price -  168.35
# diff -  0.29999999999998295
# New Stoploss -  178
# 178
# Current Price -  169.4
# Prev Price -  168.05
# 178
# Current Price -  168.6
# Prev Price -  169.4
# diff -  0.8000000000000114
# New Stoploss -  177
# 177
# Current Price -  165.0
# Prev Price -  168.6
# diff -  3.5999999999999943
# New Stoploss -  175
# 175
# Current Price -  161.6
# Prev Price -  165.0
# diff -  3.4000000000000057
# New Stoploss -  173
# 173
# Current Price -  164.0
# Prev Price -  161.6
# 173
# Current Price -  166.0
# Prev Price -  164.0
# 173
# Current Price -  165.45
# Prev Price -  166.0
# diff -  0.5500000000000114
# New Stoploss -  172
# 172
# Current Price -  161.8
# Prev Price -  165.45
# diff -  3.6499999999999773
# New Stoploss -  170
# 170
# Current Price -  162.45
# Prev Price -  161.8
# 170
# Current Price -  160.4
# Prev Price -  162.45
# diff -  2.049999999999983
# New Stoploss -  168
# 168
# Current Price -  160.8
# Prev Price -  160.4
# 168
# Current Price -  157.4
# Prev Price -  160.8
# diff -  3.4000000000000057
# New Stoploss -  166
# 166
# Current Price -  158.2
# Prev Price -  157.4
# 166
# Current Price -  162.0
# Prev Price -  158.2
# 166
# Current Price -  163.05
# Prev Price -  162.0
# 166
# Current Price -  161.7
# Prev Price -  163.05
# diff -  1.3500000000000227
# New Stoploss -  165
# 165
# Current Price -  161.25
# Prev Price -  161.7
# diff -  0.44999999999998863
# New Stoploss -  164
# 164
# Current Price -  160.05
# Prev Price -  161.25
# diff -  1.1999999999999886
# New Stoploss -  163
# 163
# Current Price -  159.2
# Prev Price -  160.05
# diff -  0.8500000000000227
# New Stoploss -  162
# 162
# Current Price -  161.45
# Prev Price -  159.2
# 162
# Current Price -  159.65
# Prev Price -  161.45
# diff -  1.799999999999983
# New Stoploss -  161
# 161
# Current Price -  157.0
# Prev Price -  159.65
# diff -  2.6500000000000057
# New Stoploss -  159
# 159
# Current Price -  154.85
# Prev Price -  157.0
# diff -  2.1500000000000057
# New Stoploss -  157
# 157
# Current Price -  152.55
# Prev Price -  154.85
# diff -  2.299999999999983
# New Stoploss -  155
# 155
# Current Price -  152.85
# Prev Price -  152.55
# 155
# Current Price -  152.55
# Prev Price -  152.85
# diff -  0.29999999999998295
# New Stoploss -  154
# 154
# Current Price -  153.65
# Prev Price -  152.55
# 154
# Current Price -  152.6
# Prev Price -  153.65
# diff -  1.0500000000000114
# New Stoploss -  153
# 153
# Current Price -  152.8
# Prev Price -  152.6
# 153
# Current Price -  153.1
# Prev Price -  152.8
# 153
# Current Price -  154.75
# Prev Price -  153.1
# 153
# Current Price -  154.3
# Prev Price -  154.75
# diff -  0.44999999999998863
# New Stoploss -  152
# 152
# Current Price -  153.85
# Prev Price -  154.3
# diff -  0.45000000000001705
# New Stoploss -  151
# 151
# Current Price -  156.15
# Prev Price -  153.85
# 151
# Current Price -  159.3
# Prev Price -  156.15
# 151
# Current Price -  159.6
# Prev Price -  159.3
# 151
# Current Price -  159.9
# Prev Price -  159.6
# 151
# Current Price -  156.3
# Prev Price -  159.9
# diff -  3.5999999999999943
# New Stoploss -  149
# 149
# Current Price -  159.65
# Prev Price -  156.3
# 149
# Current Price -  158.95
# Prev Price -  159.65
# diff -  0.700000000000017
# New Stoploss -  148
# 148
# Current Price -  156.25
# Prev Price -  158.95
# diff -  2.6999999999999886
# New Stoploss -  146
# 146
# Current Price -  156.7
# Prev Price -  156.25
# 146
# Current Price -  155.9
# Prev Price -  156.7
# diff -  0.799999999999983
# New Stoploss -  145
# 145
# Current Price -  157.9
# Prev Price -  155.9
# 145
# Current Price -  158.65
# Prev Price -  157.9
# 145
# Current Price -  158.0
# Prev Price -  158.65
# diff -  0.6500000000000057
# New Stoploss -  144
# 144
# Current Price -  157.35
# Prev Price -  158.0
# diff -  0.6500000000000057
# New Stoploss -  143
# 143
# Current Price -  160.5
# Prev Price -  157.35
# 143
# Current Price -  159.2
# Prev Price -  160.5
# diff -  1.3000000000000114
# New Stoploss -  142
# 142
# Current Price -  159.8
# Prev Price -  159.2
# 142
# Current Price -  161.8
# Prev Price -  159.8
# 142
# Current Price -  163.5
# Prev Price -  161.8
# 142
# Current Price -  161.95
# Prev Price -  163.5
# diff -  1.5500000000000114
# New Stoploss -  141
# 141
# Current Price -  163.05
# Prev Price -  161.95
# 141
# Current Price -  163.6
# Prev Price -  163.05
# 141
# Current Price -  165.3
# Prev Price -  163.6
# 141
# Current Price -  164.4
# Prev Price -  165.3
# diff -  0.9000000000000057
# New Stoploss -  140
# 140
# Current Price -  165.1
# Prev Price -  164.4
# 140
# Current Price -  165.25
# Prev Price -  165.1
# 140
# Current Price -  166.05
# Prev Price -  165.25
# 140
# Current Price -  165.25
# Prev Price -  166.05
# diff -  0.8000000000000114
# New Stoploss -  139
# 139
# Current Price -  164.05
# Prev Price -  165.25
# diff -  1.1999999999999886
# New Stoploss -  138
# 138
# Current Price -  163.35
# Prev Price -  164.05
# diff -  0.700000000000017
# New Stoploss -  137
# 137
# Current Price -  169.15
# Prev Price -  163.35
# 137
# Current Price -  174.8
# Prev Price -  169.15
# 137
# Current Price -  174.9
# Prev Price -  174.8
# 137
# Current Price -  167.7
# Prev Price -  174.9
# diff -  7.200000000000017
# New Stoploss -  133
# 133
# Current Price -  170.6
# Prev Price -  167.7
# 133
# Current Price -  170.1
# Prev Price -  170.6
# diff -  0.5
# New Stoploss -  132
# 132
# Current Price -  170.3
# Prev Price -  170.1
# 132
# Current Price -  169.9
# Prev Price -  170.3
# diff -  0.4000000000000057
# New Stoploss -  131
# 131
# Current Price -  169.75
# Prev Price -  169.9
# diff -  0.15000000000000568
# New Stoploss -  130
# 130
# Current Price -  170.8
# Prev Price -  169.75
# 130
# Current Price -  171.3
# Prev Price -  170.8
# 130
# Current Price -  170.35
# Prev Price -  171.3
# diff -  0.950000000000017
# New Stoploss -  129
# 129
# Current Price -  172.7
# Prev Price -  170.35
# 129
# Current Price -  172.85
# Prev Price -  172.7
# 129
# Current Price -  171.6
# Prev Price -  172.85
# diff -  1.25
# New Stoploss -  128
# 128
# Current Price -  171.2
# Prev Price -  171.6
# diff -  0.4000000000000057
# New Stoploss -  127
# 127
# Current Price -  171.0
# Prev Price -  171.2
# diff -  0.19999999999998863
# New Stoploss -  126
# 126
# Current Price -  169.5
# Prev Price -  171.0
# diff -  1.5
# New Stoploss -  125
# 125
# Current Price -  170.85
# Prev Price -  169.5
# 125
# Current Price -  171.0
# Prev Price -  170.85
# 125
# Current Price -  170.2
# Prev Price -  171.0
# diff -  0.8000000000000114
# New Stoploss -  124
# 124
# Current Price -  169.95
# Prev Price -  170.2
# diff -  0.25
# New Stoploss -  123
# 123
# Current Price -  167.15
# Prev Price -  169.95
# diff -  2.799999999999983
# New Stoploss -  121
# 121
# Current Price -  171.4
# Prev Price -  167.15
# 121
# Current Price -  174.25
# Prev Price -  171.4
# 121
# Current Price -  171.5
# Prev Price -  174.25
# diff -  2.75
# New Stoploss -  119
# 119
# Current Price -  171.3
# Prev Price -  171.5
# diff -  0.19999999999998863
# New Stoploss -  118
# 118
# Current Price -  170.85
# Prev Price -  171.3
# diff -  0.45000000000001705
# New Stoploss -  117
# 117
# Current Price -  173.5
# Prev Price -  170.85
# 117
# Current Price -  175.4
# Prev Price -  173.5
# 117
# Current Price -  174.5
# Prev Price -  175.4
# diff -  0.9000000000000057
# New Stoploss -  116
# 116
# Current Price -  175.6
# Prev Price -  174.5
# 116
# Current Price -  174.2
# Prev Price -  175.6
# diff -  1.4000000000000057
# New Stoploss -  115
# 115
# Current Price -  174.1
# Prev Price -  174.2
# diff -  0.09999999999999432
# New Stoploss -  114
# 114
# Current Price -  173.0
# Prev Price -  174.1
# diff -  1.0999999999999943
# New Stoploss -  113
# 113
# Current Price -  170.25
# Prev Price -  173.0
# diff -  2.75
# New Stoploss -  111
# 111
# Current Price -  168.4
# Prev Price -  170.25
# diff -  1.8499999999999943
# New Stoploss -  110
# 110
# Current Price -  169.6
# Prev Price -  168.4
# 110
# Current Price -  166.85
# Prev Price -  169.6
# diff -  2.75
# New Stoploss -  108
# 108
# Current Price -  163.15
# Prev Price -  166.85
# diff -  3.6999999999999886
# New Stoploss -  106
# 106
# Current Price -  162.25
# Prev Price -  163.15
# diff -  0.9000000000000057
# New Stoploss -  105
# 105
# Current Price -  164.6
# Prev Price -  162.25
# 105
# Current Price -  165.25
# Prev Price -  164.6
# 105
# Current Price -  170.4
# Prev Price -  165.25
# 105
# Current Price -  167.9
# Prev Price -  170.4
# diff -  2.5
# New Stoploss -  103
# 103
# Current Price -  166.95
# Prev Price -  167.9
# diff -  0.950000000000017
# New Stoploss -  102
# 102
# Current Price -  167.45
# Prev Price -  166.95
# 102
# Current Price -  168.05
# Prev Price -  167.45
# 102
# Current Price -  170.55
# Prev Price -  168.05
# 102
# Current Price -  170.35
# Prev Price -  170.55
# diff -  0.20000000000001705
# New Stoploss -  101
# 101
# Current Price -  171.7
# Prev Price -  170.35
# 101
# Current Price -  171.95
# Prev Price -  171.7
# 101
# Current Price -  170.85
# Prev Price -  171.95
# diff -  1.0999999999999943
# New Stoploss -  100
# 100
# Current Price -  169.85
# Prev Price -  170.85
# diff -  1.0
# New Stoploss -  99
# 99
# Current Price -  169.3
# Prev Price -  169.85
# diff -  0.549999999999983
# New Stoploss -  98
# 98
# Current Price -  167.8
# Prev Price -  169.3
# diff -  1.5
# New Stoploss -  97
# 97
# Current Price -  166.85
# Prev Price -  167.8
# diff -  0.950000000000017
# New Stoploss -  96
# 96
# Current Price -  165.95
# Prev Price -  166.85
# diff -  0.9000000000000057
# New Stoploss -  95
# 95
# Current Price -  163.75
# Prev Price -  165.95
# diff -  2.1999999999999886
# New Stoploss -  93
# 93
# Current Price -  163.65
# Prev Price -  163.75
# diff -  0.09999999999999432
# New Stoploss -  92
# 92
# Current Price -  166.2
# Prev Price -  163.65
# 92
# Current Price -  168.85
# Prev Price -  166.2
# 92
# Current Price -  171.95
# Prev Price -  168.85
# 92
# Current Price -  172.45
# Prev Price -  171.95
# 92
# Current Price -  172.9
# Prev Price -  172.45
# 92
# Current Price -  172.6
# Prev Price -  172.9
# diff -  0.30000000000001137
# New Stoploss -  91
# 91
# Current Price -  170.6
# Prev Price -  172.6
# diff -  2.0
# New Stoploss -  90
# 90
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-78-d30dd8ebe299> in <cell line: 0>()
#      51         time.sleep(15)
#      52
# ---> 53 trailing_stoploss("250127000323307", 0.50, "250127000322889")
#      54
#
# <ipython-input-78-d30dd8ebe299> in trailing_stoploss(orderid_sl, trailing_stoploss, orderid)
#      49             smartApi.modifyOrder(new_params)
#      50
# ---> 51         time.sleep(15)
#      52
#      53 trailing_stoploss("250127000323307", 0.50, "250127000322889")
#
# KeyboardInterrupt:
